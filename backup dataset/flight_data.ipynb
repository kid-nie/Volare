# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airline_sample_data.csv')

# %%
print(df)
# Out:
#    AIRCRAFT_TYPE    ROUTE    AIRLINE DEPARTURE_LOCATION ARRIVAL_LOCATION  \
# 0     Boeing 777  DXB-JFK   EMIRATES              Dubai         New York
# 1    Airbus A380  DXB-LHR   EMIRATES              Dubai           London
# 2     Boeing 777  DXB-SYD   EMIRATES              Dubai           Sydney
# 3     Boeing 787  DXB-DEL   EMIRATES              Dubai            Delhi
# 4     Boeing 787  AUH-LHR    ETHIHAD          Abu Dhabi           London
# 5    Airbus A350  AUH-JFK    ETHIHAD          Abu Dhabi         New York
# 6     Boeing 777  AUH-SYD    ETHIHAD          Abu Dhabi           Sydney
# 7    Airbus A321  AUH-BOM    ETHIHAD          Abu Dhabi           Mumbai
# 8     Boeing 787  DEL-JFK  AIR INDIA              Delhi         New York
# 9    Airbus A320  DEL-BLR  AIR INDIA              Delhi        Bangalore
# 10    Boeing 777  DEL-LHR  AIR INDIA              Delhi           London
# 11   Airbus A321  BOM-DXB  AIR INDIA             Mumbai            Dubai
# ...

# %%
df[df["ARRIVAL_LOCATION"] == "Paris"] #by location paris
# Out:
# Empty DataFrame
# Columns: [AIRCRAFT_TYPE, ROUTE, AIRLINE, DEPARTURE_LOCATION, ARRIVAL_LOCATION, DEPARTURE_TIME, ARRIVAL_TIME, TRAVEL_TIME, CONNECTING, DATE_DEPARTURE, PRICE]
# Index: []

# %%
df[df["ARRIVAL_LOCATION"] == "Dubai"] #by location dubai
# Out:
#    AIRCRAFT_TYPE    ROUTE    AIRLINE DEPARTURE_LOCATION ARRIVAL_LOCATION  \
# 11   Airbus A321  BOM-DXB  AIR INDIA             Mumbai            Dubai
#
#    DEPARTURE_TIME ARRIVAL_TIME TRAVEL_TIME CONNECTING DATE_DEPARTURE  PRICE
# 11          20:10        22:00      2h 50m         No     2026-05-18    300

# %%
df[df["AIRLINE"] == "EMIRATES"] #by airline
# Out:
#   AIRCRAFT_TYPE    ROUTE   AIRLINE DEPARTURE_LOCATION ARRIVAL_LOCATION  \
# 0    Boeing 777  DXB-JFK  EMIRATES              Dubai         New York
# 1   Airbus A380  DXB-LHR  EMIRATES              Dubai           London
# 2    Boeing 777  DXB-SYD  EMIRATES              Dubai           Sydney
# 3    Boeing 787  DXB-DEL  EMIRATES              Dubai            Delhi
#
#   DEPARTURE_TIME ARRIVAL_TIME TRAVEL_TIME CONNECTING DATE_DEPARTURE  PRICE
# 0          08:30        14:20     14h 50m         No     2026-05-10   1200
# 1          02:15        06:45      7h 30m         No     2026-05-12    900
# 2          21:00        17:30     14h 30m        Yes     2026-05-15   1500
# 3          09:50        14:40      3h 50m         No     2026-05-18    400

# %%
#sorting by price 
df[df["AIRLINE"] == "EMIRATES"].sort_values("PRICE")
# Out:
#   AIRCRAFT_TYPE    ROUTE   AIRLINE DEPARTURE_LOCATION ARRIVAL_LOCATION  \
# 3    Boeing 787  DXB-DEL  EMIRATES              Dubai            Delhi
# 1   Airbus A380  DXB-LHR  EMIRATES              Dubai           London
# 0    Boeing 777  DXB-JFK  EMIRATES              Dubai         New York
# 2    Boeing 777  DXB-SYD  EMIRATES              Dubai           Sydney
#
#   DEPARTURE_TIME ARRIVAL_TIME TRAVEL_TIME CONNECTING DATE_DEPARTURE  PRICE
# 3          09:50        14:40      3h 50m         No     2026-05-18    400
# 1          02:15        06:45      7h 30m         No     2026-05-12    900
# 0          08:30        14:20     14h 50m         No     2026-05-10   1200
# 2          21:00        17:30     14h 30m        Yes     2026-05-15   1500

# %%
df[df["PRICE"] <= 500]
# Out:
#    AIRCRAFT_TYPE    ROUTE    AIRLINE DEPARTURE_LOCATION ARRIVAL_LOCATION  \
# 3     Boeing 787  DXB-DEL   EMIRATES              Dubai            Delhi
# 7    Airbus A321  AUH-BOM    ETHIHAD          Abu Dhabi           Mumbai
# 9    Airbus A320  DEL-BLR  AIR INDIA              Delhi        Bangalore
# 11   Airbus A321  BOM-DXB  AIR INDIA             Mumbai            Dubai
# 12   Airbus A320  DEL-BOM     INDIGO              Delhi           Mumbai
# 13   Airbus A321  BLR-DEL     INDIGO          Bangalore            Delhi
# 14        ATR 72  CCU-GAU     INDIGO            Kolkata         Guwahati
# 15   Airbus A320  HYD-DEL     INDIGO          Hyderabad            Delhi
# 16    Boeing 737  DXB-KWI  FLY DUBAI              Dubai           Kuwait
# 17    Boeing 737  DXB-MCT  FLY DUBAI              Dubai           Muscat
# 18    Boeing 737  DXB-DEL  FLY DUBAI              Dubai            Delhi
# 19    Boeing 737  DXB-IST  FLY DUBAI              Dubai         Istanbul
#
# ...
